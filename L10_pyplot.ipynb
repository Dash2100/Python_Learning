# %%
#%matplotlib notebook
import matplotlib.pyplot as plt
data = [-1, -4.3, 15, 21, 31]
plt.figure(num=3,figsize=(8,5))
plt.plot(data)
plt.show()

# %%
import matplotlib.pyplot as plt
ydata = [78, 92, 65, 98, 72]
xdata = ['chinese','english','math','history','nature']
plt.figure(num=3, figsize=(8,5))
plt.plot(xdata,ydata)
plt.show()

# %%
import matplotlib.pyplot as plt
ydata1 = [78, 92, 65, 98, 72]
ydata2 = [50, 70, 35, 78, 22]
xdata = ['chinese','english','math','history','nature']
plt.figure(num=3, figsize=(8,5))
plt.plot(xdata,ydata1,ydata2)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(['chinese','english','math','history','discover'],[1,2,3,4,5],'b--')

# %%
x = [1,2,3,4,5]
y1 = [1, 2, 5, 6,7]
y2 = [4, 5, 6, 7, 8]
plt.plot(x, y1, 'r-o' , x, y2, 'g--')
plt.grid()
